# %%
import numpy as np
from sklearn import preprocessing
import os
import librosa
import torch

# %%
label_encoder = preprocessing.LabelEncoder()
onehot_encoder = preprocessing.OneHotEncoder()

# %%
a=np.genfromtxt('/home/libedev/mute/mute-hero/download/dataset/new_train_labels.txt', encoding='ascii',dtype=int)

# %%
print(a)
print(len(a))

#np.save("/home/libedev/mute/mute-hero/download/dataset/new_test_label.npy",a)
# Out:
# [7 7 4 4 0 6 7 5 1 2 7 6 6 2 5 3 0 7 7 4 5 3 3 1 0 1 3 7 3 5 6 0 3 0 1 3 0
#  7 0 2 2 0 3 4 4 4 4 7 3 4 2 7 0 7 0 0 5 2 3 5 7 5 1 7 3 6 4 5 2 0 4 3 1 4
#  6 1 7 1 2 2 2 1 3 7 7 6 0 7 0 3 6 3 1 0 5 4 4 3 5 3 1 7 5 2 0 6 0 7 4 4 1
#  1 6 3 0 1 1 3 5 7 7 5 0 5 7 2 6 4 3 4 3 1 7 2 4 4 7 1 0 4 5 7 3 4 0 1 7 3
#  0 7 6 4 3 6 2 2 2 6 2 0 7 7 6 6 1 5 4 5 5 4 3 4 4 4 6 7 5 3 3 6 5 6 2 1 7
#  3 2 0 0 1 7 0 0 0 6 6 1 6 1 2 1 6 5 7 2 5 3 3 3 1 4 0 2 3 7 7 5 3 1 7 1 0
#  1 7 6 0 4 2 2 0 5 0 7 1 4 6 7 3 5 6 0 0 4 5 4 3 2 6 0 2 5 3 4 4 2 2 3 5 2
#  6 1 4 1 6 3 7 2 5 2 6 7 5 6 4 2 5 6 2 2 3 5 2 4 2 5 6 4 0 5 1 2 3 5 4 5 0
#  1 7 1 4 4 4 3 3 4 6 6 0 3 5 6 1 2 4 4 6 0 6 2 3 3 4 7 2 3 3 6 1 5 4 2 2 5
#  0 0 6 5 1 1 6 1 6 4 4 2 0 5 2 1 3 0 1 1 1 1 5 2 2 0 0 5 5 0 1 7 7 1 0 7 3
#  7 7 6 5 2 0 6 0 6 1 1 6 4 2 5 1 6 7 5 5 5 6 6 2 6 2 7 5 1 3]
# 400

# %% [markdown]
# ## 여기서 부터 numpy 시작

# %%
c=[]

# %%
d = c.append(np.load('/home/libedev/mute/mute-hero/download/dataset/new_train_label.npy'))

# %%
d

# %%
c = np.load('/home/libedev/mute/mute-hero/download/dataset/new_train_label.npy')

# %%
c
# Out:
# array([7, 7, 4, 4, 0, 6, 7, 5, 1, 2, 7, 6, 6, 2, 5, 3, 0, 7, 7, 4, 5, 3,
#        3, 1, 0, 1, 3, 7, 3, 5, 6, 0, 3, 0, 1, 3, 0, 7, 0, 2, 2, 0, 3, 4,
#        4, 4, 4, 7, 3, 4, 2, 7, 0, 7, 0, 0, 5, 2, 3, 5, 7, 5, 1, 7, 3, 6,
#        4, 5, 2, 0, 4, 3, 1, 4, 6, 1, 7, 1, 2, 2, 2, 1, 3, 7, 7, 6, 0, 7,
#        0, 3, 6, 3, 1, 0, 5, 4, 4, 3, 5, 3, 1, 7, 5, 2, 0, 6, 0, 7, 4, 4,
#        1, 1, 6, 3, 0, 1, 1, 3, 5, 7, 7, 5, 0, 5, 7, 2, 6, 4, 3, 4, 3, 1,
#        7, 2, 4, 4, 7, 1, 0, 4, 5, 7, 3, 4, 0, 1, 7, 3, 0, 7, 6, 4, 3, 6,
#        2, 2, 2, 6, 2, 0, 7, 7, 6, 6, 1, 5, 4, 5, 5, 4, 3, 4, 4, 4, 6, 7,
#        5, 3, 3, 6, 5, 6, 2, 1, 7, 3, 2, 0, 0, 1, 7, 0, 0, 0, 6, 6, 1, 6,
#        1, 2, 1, 6, 5, 7, 2, 5, 3, 3, 3, 1, 4, 0, 2, 3, 7, 7, 5, 3, 1, 7,
#        1, 0, 1, 7, 6, 0, 4, 2, 2, 0, 5, 0, 7, 1, 4, 6, 7, 3, 5, 6, 0, 0,
#        4, 5, 4, 3, 2, 6, 0, 2, 5, 3, 4, 4, 2, 2, 3, 5, 2, 6, 1, 4, 1, 6,
#        3, 7, 2, 5, 2, 6, 7, 5, 6, 4, 2, 5, 6, 2, 2, 3, 5, 2, 4, 2, 5, 6,
# ...

# %%
labels_data=[]
print(c.shape)
for i in c:
    labels_data.append(i)
# Out:
# (400,)

# %%
labels_data = np.array(labels_data)
labels_data = labels_data.reshape(400,1,1,1)

# %%
labels_data.shape
# Out:
# (400, 1, 1, 1)

# %%
f_x = torch.from_numpy(labels_data)

# %%
f_x
# Out:
# tensor([[[[7]]],
#
#
#         [[[7]]],
#
#
#         [[[4]]],
#
#
#         [[[4]]],
#
#
#         [[[0]]],
#
#
#         [[[6]]],
#
#
#         [[[7]]],
#
#
#         [[[5]]],
#
#
#         [[[1]]],
#
#
#         [[[2]]],
#
#
#         [[[7]]],
#
#
#         [[[6]]],
#
#
#         [[[6]]],
#
#
#         [[[2]]],
#
#
#         [[[5]]],
#
#
#         [[[3]]],
#
#
#         [[[0]]],
#
#
#         [[[7]]],
#
#
#         [[[7]]],
#
#
#         [[[4]]],
#
#
#         [[[5]]],
#
#
#         [[[3]]],
#
#
#         [[[3]]],
#
#
#         [[[1]]],
#
#
#         [[[0]]],
#
#
#         [[[1]]],
#
#
#         [[[3]]],
#
#
#         [[[7]]],
#
#
#         [[[3]]],
#
#
#         [[[5]]],
#
#
#         [[[6]]],
#
#
#         [[[0]]],
#
#
#         [[[3]]],
#
#
#         [[[0]]],
#
#
#         [[[1]]],
#
#
#         [[[3]]],
#
#
#         [[[0]]],
#
#
#         [[[7]]],
#
#
#         [[[0]]],
#
#
#         [[[2]]],
#
#
#         [[[2]]],
#
#
#         [[[0]]],
#
#
#         [[[3]]],
#
#
# ...

# %%
x = torch.from_numpy(c)
x
# Out:
# tensor([7, 7, 4, 4, 0, 6, 7, 5, 1, 2, 7, 6, 6, 2, 5, 3, 0, 7, 7, 4, 5, 3, 3, 1,
#         0, 1, 3, 7, 3, 5, 6, 0, 3, 0, 1, 3, 0, 7, 0, 2, 2, 0, 3, 4, 4, 4, 4, 7,
#         3, 4, 2, 7, 0, 7, 0, 0, 5, 2, 3, 5, 7, 5, 1, 7, 3, 6, 4, 5, 2, 0, 4, 3,
#         1, 4, 6, 1, 7, 1, 2, 2, 2, 1, 3, 7, 7, 6, 0, 7, 0, 3, 6, 3, 1, 0, 5, 4,
#         4, 3, 5, 3, 1, 7, 5, 2, 0, 6, 0, 7, 4, 4, 1, 1, 6, 3, 0, 1, 1, 3, 5, 7,
#         7, 5, 0, 5, 7, 2, 6, 4, 3, 4, 3, 1, 7, 2, 4, 4, 7, 1, 0, 4, 5, 7, 3, 4,
#         0, 1, 7, 3, 0, 7, 6, 4, 3, 6, 2, 2, 2, 6, 2, 0, 7, 7, 6, 6, 1, 5, 4, 5,
#         5, 4, 3, 4, 4, 4, 6, 7, 5, 3, 3, 6, 5, 6, 2, 1, 7, 3, 2, 0, 0, 1, 7, 0,
#         0, 0, 6, 6, 1, 6, 1, 2, 1, 6, 5, 7, 2, 5, 3, 3, 3, 1, 4, 0, 2, 3, 7, 7,
#         5, 3, 1, 7, 1, 0, 1, 7, 6, 0, 4, 2, 2, 0, 5, 0, 7, 1, 4, 6, 7, 3, 5, 6,
#         0, 0, 4, 5, 4, 3, 2, 6, 0, 2, 5, 3, 4, 4, 2, 2, 3, 5, 2, 6, 1, 4, 1, 6,
#         3, 7, 2, 5, 2, 6, 7, 5, 6, 4, 2, 5, 6, 2, 2, 3, 5, 2, 4, 2, 5, 6, 4, 0,
# ...

# %%
f_x = torch.from_numpy()
