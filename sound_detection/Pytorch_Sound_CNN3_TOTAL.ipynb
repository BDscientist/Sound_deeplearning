# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
import torchvision.utils as utils
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable


import numpy as np
import random
import os
import Pyclass
import Pyclass2



from torch.utils.data import Dataset, DataLoader


import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from torchvision import models
import torchvision.utils
import torchvision.datasets as dsets
import torchvision.transforms as transforms

import numpy as np

# %% [markdown]
# # PYCLASS IMPORT

# %%
sound_train = Pyclass2.my_datset2(train = True)
                         

sound_test = Pyclass2.my_datset2(train = False)

# %%
batch_size = 81

train_loader  = DataLoader(dataset=sound_train,
                                           batch_size=batch_size,
                                           shuffle=False
                                           ,num_workers=1)

test_loader = DataLoader(dataset=sound_test,
                                         batch_size=batch_size,
                                         shuffle=False,
                        num_workers=1)

# %%
print(sound_train.train_data.shape)
print(sound_train.train_label.shape)
print(sound_train.train_data.dtype)
# Out:
# torch.Size([6723, 1, 10, 20])
# torch.Size([6723])
# torch.float32

# %% [markdown]
# # DEFINE MODEL

# %%
class CNN(nn.Module):
    def __init__(self):
        
        super(CNN, self).__init__()
        
        self.layer = nn.Sequential(
            nn.Conv2d(in_channels = 1,out_channels=16,kernel_size = 3),
            nn.ReLU(),
            nn.Dropout2d(0.5),
            nn.Conv2d(in_channels=16,out_channels=32,kernel_size = 3),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Dropout2d(0.5),
            nn.Conv2d(in_channels = 32,out_channels = 64,kernel_size = 3),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
            
        )
        
        
        self.fc_layer = nn.Sequential(
            nn.Linear(64*3*1,1000),
            nn.ReLU(),
            nn.Linear(1000,300),
            nn.ReLU(),
            nn.Linear(300,100),
            nn.ReLU(),
            nn.Linear(100,11),
            nn.Softmax()
        )       
        
    def forward(self,x):
        print(x.data.shape)
        out = self.layer(x)
        out = out.view(out.shape[0],-1)
        out = self.fc_layer(out)

        return out

# %%
model = CNN().cuda()

# %%
loss = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# # TRAIN MODEL

# %%
num_epochs = 500

# %%
save_path = '/home/libedev/mute/mute-hero/download/dataset/model2/'
model_path = save_path + 'model.pkl'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
if os.path.isfile(model_path):
    model.load_state_dict(torch.load(model_path))
    print("Model Loaded!")

else:
    
    for epoch in range(num_epochs):

        total_batch = len(sound_train) // batch_size

        for i, (batch_images, batch_labels) in enumerate(train_loader):

            X = batch_images.cuda()
            Y = batch_labels.cuda()

            pre = model(X)
            cost = loss(pre, Y)

            optimizer.zero_grad()
            cost.backward()
            optimizer.step()

            if (i+1) % 10 == 0:
                print('Epoch [%d/%d], lter [%d/%d], Loss: %.4f'
                     %(epoch+1, num_epochs, i+1, total_batch, cost.item()))

    if not os.path.isfile(model_path):
        print("Model Saved!")
        torch.save(model.state_dict(), model_path)
# Out:
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# /home/libedev/anaconda3/envs/mute/lib/python3.6/site-packages/torch/nn/modules/container.py:92: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [10/83], Loss: 2.3823
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [20/83], Loss: 2.3731
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [30/83], Loss: 2.4008
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [40/83], Loss: 2.3556
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [50/83], Loss: 2.3432
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [60/83], Loss: 2.3565
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [70/83], Loss: 2.3764
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [1/500], lter [80/83], Loss: 2.3306
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [10/83], Loss: 2.3003
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [20/83], Loss: 2.2959
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [30/83], Loss: 2.4174
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [40/83], Loss: 2.2943
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [50/83], Loss: 2.2951
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [60/83], Loss: 2.3060
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [70/83], Loss: 2.2826
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [2/500], lter [80/83], Loss: 2.1804
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [10/83], Loss: 2.2915
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [20/83], Loss: 2.3608
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [30/83], Loss: 2.3664
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [40/83], Loss: 2.3392
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [50/83], Loss: 2.3425
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [60/83], Loss: 2.2924
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [70/83], Loss: 2.2575
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [3/500], lter [80/83], Loss: 2.2274
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [10/83], Loss: 2.2289
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [20/83], Loss: 2.3035
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [30/83], Loss: 2.2427
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [40/83], Loss: 2.2439
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [50/83], Loss: 2.2461
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [60/83], Loss: 2.3390
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [70/83], Loss: 2.2411
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [4/500], lter [80/83], Loss: 2.2082
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [10/83], Loss: 2.2043
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [20/83], Loss: 2.3051
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [30/83], Loss: 2.2579
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [40/83], Loss: 2.2287
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [50/83], Loss: 2.2502
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [60/83], Loss: 2.2459
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [70/83], Loss: 2.2363
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [5/500], lter [80/83], Loss: 2.2230
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [10/83], Loss: 2.1464
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [20/83], Loss: 2.2581
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [30/83], Loss: 2.1457
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [40/83], Loss: 2.2474
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [50/83], Loss: 2.2704
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [60/83], Loss: 2.3417
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [70/83], Loss: 2.1933
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [6/500], lter [80/83], Loss: 2.1924
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [10/83], Loss: 2.2327
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [20/83], Loss: 2.2554
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [30/83], Loss: 2.1543
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [40/83], Loss: 2.1752
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [50/83], Loss: 2.2086
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [60/83], Loss: 2.2630
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [70/83], Loss: 2.1965
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [7/500], lter [80/83], Loss: 2.1631
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [10/83], Loss: 2.1968
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [20/83], Loss: 2.2638
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [30/83], Loss: 2.2139
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [40/83], Loss: 2.1314
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [50/83], Loss: 2.2160
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [60/83], Loss: 2.2700
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [70/83], Loss: 2.1742
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [8/500], lter [80/83], Loss: 2.1798
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [10/83], Loss: 2.0775
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [20/83], Loss: 2.2108
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [30/83], Loss: 2.1702
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [40/83], Loss: 2.1694
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [50/83], Loss: 2.2418
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [60/83], Loss: 2.2726
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [70/83], Loss: 2.1747
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [9/500], lter [80/83], Loss: 2.2173
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [10/83], Loss: 2.1598
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [20/83], Loss: 2.2571
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [30/83], Loss: 2.1577
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [40/83], Loss: 2.2072
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [50/83], Loss: 2.2022
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [60/83], Loss: 2.2083
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [70/83], Loss: 2.1497
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [10/500], lter [80/83], Loss: 2.1887
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [10/83], Loss: 2.1305
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [20/83], Loss: 2.2597
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [30/83], Loss: 2.1547
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [40/83], Loss: 2.1412
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [50/83], Loss: 2.1932
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [60/83], Loss: 2.1691
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [70/83], Loss: 2.1137
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [11/500], lter [80/83], Loss: 2.1463
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [10/83], Loss: 2.1997
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [20/83], Loss: 2.2475
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [30/83], Loss: 2.1867
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [40/83], Loss: 2.1523
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [50/83], Loss: 2.1335
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [60/83], Loss: 2.2286
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [70/83], Loss: 2.1792
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [12/500], lter [80/83], Loss: 2.2163
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [10/83], Loss: 2.1103
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [20/83], Loss: 2.2271
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [30/83], Loss: 2.1115
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [40/83], Loss: 2.0593
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [50/83], Loss: 2.1650
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [60/83], Loss: 2.1788
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [70/83], Loss: 2.1460
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [13/500], lter [80/83], Loss: 2.1835
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [10/83], Loss: 2.0893
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [20/83], Loss: 2.2737
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [30/83], Loss: 2.1540
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [40/83], Loss: 2.1595
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [50/83], Loss: 2.2017
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [60/83], Loss: 2.2133
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [70/83], Loss: 2.2063
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [14/500], lter [80/83], Loss: 2.1841
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [10/83], Loss: 2.1384
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [20/83], Loss: 2.2489
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [30/83], Loss: 2.0900
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [40/83], Loss: 2.0904
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [50/83], Loss: 2.2032
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [60/83], Loss: 2.2201
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [70/83], Loss: 2.1820
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [15/500], lter [80/83], Loss: 2.1706
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [10/83], Loss: 2.1194
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [20/83], Loss: 2.2529
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [30/83], Loss: 2.0604
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [40/83], Loss: 2.0526
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [50/83], Loss: 2.1897
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [60/83], Loss: 2.1836
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [70/83], Loss: 2.1594
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [16/500], lter [80/83], Loss: 2.1757
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [10/83], Loss: 2.0717
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [20/83], Loss: 2.2387
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [30/83], Loss: 2.0780
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [40/83], Loss: 2.1065
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [50/83], Loss: 2.1816
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [60/83], Loss: 2.1790
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [70/83], Loss: 2.1073
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [17/500], lter [80/83], Loss: 2.1086
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [10/83], Loss: 2.1235
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [20/83], Loss: 2.2321
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [30/83], Loss: 1.9770
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [40/83], Loss: 2.0425
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [50/83], Loss: 2.1840
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [60/83], Loss: 2.1667
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [18/500], lter [70/83], Loss: 2.1104
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# ...
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [10/83], Loss: 1.6595
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [20/83], Loss: 1.7221
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [30/83], Loss: 1.7260
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [40/83], Loss: 1.6159
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [50/83], Loss: 1.6787
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [60/83], Loss: 1.6009
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [70/83], Loss: 1.6756
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [495/500], lter [80/83], Loss: 1.6520
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [10/83], Loss: 1.6525
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [20/83], Loss: 1.7393
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [30/83], Loss: 1.7161
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [40/83], Loss: 1.6267
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [50/83], Loss: 1.6794
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [60/83], Loss: 1.6066
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [70/83], Loss: 1.7301
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [496/500], lter [80/83], Loss: 1.6303
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [10/83], Loss: 1.6217
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [20/83], Loss: 1.6939
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [30/83], Loss: 1.6903
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [40/83], Loss: 1.6146
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [50/83], Loss: 1.6665
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [60/83], Loss: 1.6219
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [70/83], Loss: 1.7511
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [497/500], lter [80/83], Loss: 1.6546
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [10/83], Loss: 1.6194
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [20/83], Loss: 1.7392
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [30/83], Loss: 1.7333
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [40/83], Loss: 1.6513
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [50/83], Loss: 1.6912
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [60/83], Loss: 1.6291
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [70/83], Loss: 1.6589
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [498/500], lter [80/83], Loss: 1.6546
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [10/83], Loss: 1.6676
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [20/83], Loss: 1.6854
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [30/83], Loss: 1.7159
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [40/83], Loss: 1.6481
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [50/83], Loss: 1.6677
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [60/83], Loss: 1.6222
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [70/83], Loss: 1.7132
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [499/500], lter [80/83], Loss: 1.6419
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [10/83], Loss: 1.6562
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [20/83], Loss: 1.7160
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [30/83], Loss: 1.6835
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [40/83], Loss: 1.6774
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [50/83], Loss: 1.6880
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [60/83], Loss: 1.6618
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [70/83], Loss: 1.6854
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Epoch [500/500], lter [80/83], Loss: 1.6295
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# Model Saved!

# %% [markdown]
# # inception_transfer_learning

# %%
model = models.inception_v3(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-1a9a5a14.pth" to /home/libedev/.cache/torch/checkpoints/inception_v3_google-1a9a5a14.pth
# 22.6%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 58.1%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# 93.7%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
model
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
model.aux_logits = False

fine_tune = False

if not fine_tune:
    for parameter in model.parameters():
        parameter.requires_grad = False

# %%
model.fc = nn.Sequential(
    nn.Linear(model.fc.in_features, 100),
    nn.Linear(100,11)
)

# %%
model = model.cuda()

# %%
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(filter(lambda p: p.requires_grad, model.parameters()), lr=0.001)

# %%
num_epochs = 1000

# %%
save_path = '/home/libedev/mute/mute-hero/download/dataset/model2/'
model_path = save_path + 'model.pkl'
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
if os.path.isfile(model_path):
    model.load_state_dict(torch.load(model_path))
    print("Model Loaded!")

else:
    
    for epoch in range(num_epochs):

        total_batch = len(sound_train) // batch_size

        for i, (batch_images, batch_labels) in enumerate(train_loader):

            X = batch_images.cuda()
            Y = batch_labels.cuda()

            pre = model(X)
            cost = loss(pre, Y)

            optimizer.zero_grad()
            cost.backward()
            optimizer.step()

            if (i+1) % 10 == 0:
                print('Epoch [%d/%d], lter [%d/%d], Loss: %.4f'
                     %(epoch+1, num_epochs, i+1, total_batch, cost.item()))

    if not os.path.isfile(model_path):
        print("Model Saved!")
        torch.save(model.state_dict(), model_path)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-929ea5936822> in <module>
#      14             Y = batch_labels.cuda()
#      15
# ---> 16             pre = model(X)
#      17             cost = loss(pre, Y)
#      18
#
# ~/anaconda3/envs/mute/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/mute/lib/python3.6/site-packages/torchvision/models/inception.py in forward(self, x)
#      76         if self.transform_input:
#      77             x_ch0 = torch.unsqueeze(x[:, 0], 1) * (0.229 / 0.5) + (0.485 - 0.5) / 0.5
# ---> 78             x_ch1 = torch.unsqueeze(x[:, 1], 1) * (0.224 / 0.5) + (0.456 - 0.5) / 0.5
#      79             x_ch2 = torch.unsqueeze(x[:, 2], 1) * (0.225 / 0.5) + (0.406 - 0.5) / 0.5
#      80             x = torch.cat((x_ch0, x_ch1, x_ch2), 1)
#
# IndexError: index 1 is out of bounds for dimension 1 with size 1

# %% [markdown]
# # TEST MODEL

# %%
model.eval()

correct = 0
total = 0

for sound, labels in test_loader:
    
    sound = sound.cuda()
    outputs = model(sound)
    
    _, predicted = torch.max(outputs.data, 1)
    
    total += labels.size(0)
    correct += (predicted == labels.cuda()).sum()
    
print('Accuracy of test sound: %f %%' % (100 * float(correct) / total))
# Out:
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([81, 1, 10, 20])
# torch.Size([71, 1, 10, 20])
# Accuracy of test sound: 51.471550 %
