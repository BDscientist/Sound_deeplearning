# %%
import os

# %%
def ex_filename():
    base = '/home/libedev/mute/mute-hero/download/'
    train = 'train/'
    test = 'test/'
    
    count =50
    
    for filename in os.listdir(str(base)):
        
        if filename == 'train':
            
            for file in os.listdir(str(base)+str(train)):
                
                if file == 'total_plane' :
                    
                    for ff in os.listdir(str(base)+str(train)+str(file)):
                        print(ff)
                        count +=1
                        os.renames(str(base)+str(train)+str(file)+"/"+str(ff) , 
                                      str(base)+str(train)+str(file)+"/"+"train"+"_"+"airplane"+"_"+ str(count) +".wav")

# %%
def ex_urban():
    base = '/home/libedev/mute/mute-hero/download/urbansound/UrbanSound8K/audio/'
    train = 'fold11'
    test = 'test/'
    
    count =0
            
    for file in os.listdir(str(base)+str(train)):
       
        print(file)
                
        os.renames(str(base)+str(train)+"/"+str(file),str(base)+str(train)+"/"+"11111"+"-"+"10"+"-"+"0"+"-"+str(count)+".wav")
                       
        count +=1

# %%
if __name__ == "__main__":
    

    ex_urban()
# Out:
# train_airplane_35.wav
# train_airplane_50 (7).wav
# nextdoor (11).WAV
# train_airplane_97.wav
# train_airplane_25.wav
# train_airplane_73.wav
# train_airplane_18.wav
# beside_door (28).wav
# train_airplane_108.wav
# train_airplane_119.wav
# 1 (45).wav
# train_airplane_102.wav
# train_airplane_69.wav
# train_airplane_67.wav
# nextdoor (8).WAV
# train_airplane_81.wav
# beside_door (27).wav
# 1 (38).wav
# train_airplane_8.wav
# train_airplane_6.wav
# train_airplane_36.wav
# train_airplane_4.wav
# train_airplane_126.wav
# beside_door (31).wav
# 14.wav
# nextdoor (6).WAV
# train_airplane_113.wav
# train_airplane_9.wav
# beside_door (25).wav
# train_airplane_80.wav
# train_airplane_50.wav
# train_airplane_30.wav
# 15.wav
# train_airplane_42.wav
# nextdoor (3).WAV
# train_airplane_89.wav
# train_airplane_64.wav
# 1 (43).wav
# 10.wav
# train_airplane_60.wav
# mdoor_3.wav
# train_airplane_132.wav
# 4.wav
# train_airplane_28.wav
# train_airplane_61.wav
# train_airplane_135.wav
# beside_door (17).wav
# train_airplane_107.wav
# train_airplane_110.wav
# train_airplane_19.wav
# train_airplane_49.wav
# train_airplane_96.wav
# train_airplane_26.wav
# train_airplane_50 (10).wav
# train_airplane_71.wav
# 12.wav
# mdoor_1.wav
# train_airplane_90.wav
# 9.wav
# mdoor_2.wav
# train_airplane_127.wav
# train_airplane_85.wav
# train_airplane_118.wav
# train_airplane_128.wav
# beside_door (20).wav
# train_airplane_22.wav
# train_airplane_103.wav
# train_airplane_37.wav
# train_airplane_5.wav
# train_airplane_131.wav
# train_airplane_50 (6).wav
# train_airplane_133.wav
# train_airplane_24.wav
# train_airplane_94.wav
# 1 (40).wav
# train_airplane_123.wav
# train_airplane_50 (8).wav
# train_airplane_88.wav
# beside_door (24).wav
# train_airplane_52.wav
# train_airplane_141.wav
# train_airplane_50 (9).wav
# train_airplane_70.wav
# train_airplane_86.wav
# 5.wav
# train_airplane_139.wav
# train_airplane_13.wav
# beside_door (19).wav
# train_airplane_140.wav
# train_airplane_2.wav
# train_airplane_3.wav
# train_airplane_7.wav
# train_airplane_134.wav
# 7.wav
# train_airplane_84.wav
# train_airplane_106.wav
# 1 (44).wav
# nextdoor (15).WAV
# nextdoor (1).WAV
# train_airplane_50 (15).wav
# train_airplane_98.wav
# train_airplane_99.wav
# train_airplane_145.wav
# train_airplane_66.wav
# nextdoor (9).WAV
# train_airplane_130.wav
# 1 (37).wav
# train_airplane_63.wav
# beside_door (18).wav
# train_airplane_143.wav
# train_airplane_47.wav
# train_airplane_11.wav
# train_airplane_121.wav
# train_airplane_16.wav
# train_airplane_45.wav
# train_airplane_122.wav
# train_airplane_53.wav
# train_airplane_20.wav
# train_airplane_109.wav
# 17.wav
# train_airplane_115.wav
# 1 (42).wav
# train_airplane_111.wav
# train_airplane_56.wav
# nextdoor (5).WAV
# nextdoor (4).WAV
# train_airplane_72.wav
# train_airplane_50 (16).wav
# beside_door (22).wav
# train_airplane_100.wav
# beside_door (29).wav
# nextdoor (14).WAV
# train_airplane_46.wav
# 1 (39).wav
# train_airplane_50 (14).wav
# train_airplane_10.wav
# train_airplane_105.wav
# 3.wav
# train_airplane_116.wav
# train_airplane_1.wav
# train_airplane_117.wav
# train_airplane_12.wav
# 1.wav
# 1 (46).wav
# train_airplane_29.wav
# 1 (47).wav
# train_airplane_17.wav
# train_airplane_33.wav
# train_airplane_50 (11).wav
# train_airplane_83.wav
# train_airplane_43.wav
# train_airplane_112.wav
# train_airplane_87.wav
# train_airplane_93.wav
# train_airplane_59.wav
# 13.wav
# 1 (48).wav
# train_airplane_50 (13).wav
# nextdoor (2).WAV
# train_airplane_137.wav
# train_airplane_114.wav
# train_airplane_75.wav
# train_airplane_57.wav
# train_airplane_58.wav
# nextdoor (13).WAV
# train_airplane_78.wav
# train_airplane_68.wav
# 6.wav
# train_airplane_77.wav
# nextdoor (12).WAV
# train_airplane_91.wav
# beside_door (21).wav
# beside_door (26).wav
# train_airplane_92.wav
# train_airplane_44.wav
# train_airplane_50 (12).wav
# train_airplane_38.wav
# 8.wav
# train_airplane_95.wav
# train_airplane_65.wav
# train_airplane_125.wav
# 1 (49).wav
# beside_door (23).wav
# train_airplane_136.wav
# train_airplane_34.wav
# 16.wav
# train_airplane_48.wav
# train_airplane_138.wav
# 2.wav
# train_airplane_51.wav
# train_airplane_74.wav
# train_airplane_79.wav
# nextdoor (10).WAV
# train_airplane_23.wav
# train_airplane_21.wav
# train_airplane_55.wav
# train_airplane_124.wav
# 1 (41).wav
# train_airplane_14.wav
# train_airplane_104.wav
# train_airplane_27.wav
# train_airplane_62.wav
# train_airplane_142.wav
# nextdoor (7).WAV
# train_airplane_40.wav
# train_airplane_32.wav
# train_airplane_82.wav
# train_airplane_76.wav
# train_airplane_41.wav
# train_airplane_15.wav
# train_airplane_54.wav
# beside_door (9).wav
# train_airplane_39.wav
# train_airplane_31.wav
# 11.wav
# train_airplane_101.wav
# train_airplane_120.wav
# train_airplane_129.wav
# 1 (36).wav
# beside_door (30).wav
# train_airplane_144.wav

# %%
def ex_filename_test():
    base = '/home/libedev/mute/mute-hero/download/'
    train = 'train/'
    test = 'test/'
    
    count =20
    
    for filename in os.listdir(str(base)):    
    
        if filename  == 'test':
            
            for file in os.listdir(str(base)+str(test)):
                
                    
                    if file == 'total_plane_test' : # 변환하고 싶은 카테고리명 
                        
                        for ff in os.listdir(str(base)+str(test)+str(file)):
                            count +=1
                            
                            os.renames(str(base)+str(test)+str(file)+"/"+str(ff) , 
                                      str(base)+str(test)+str(file)+"/"+"test"+"_"+"airplane"+"_"+ str(count) +".wav")

# %%
if __name__ == "__main__":
    

    ex_filename_test()
